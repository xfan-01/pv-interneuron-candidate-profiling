# %% [markdown]
# # Quickstart: Unified Notebook Entry
#
# Use this notebook to verify environment, paths, configs, data, and checkpoints before running analysis notebooks.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print('Project root:', ROOT)
print('Python:', sys.version)

# %%
from model.utils.config import load_yaml_config
from model.utils.constants import (
    get_cluster_column,
    get_time_column,
    get_cluster_labels,
    get_pv_identity_markers,
    get_pv_path_nodes,
)

required = [
    ROOT / 'data' / 'labelled_data.h5ad',
    ROOT / 'checkpoints' / 'classifier' / 'best_classifier.pth',
    ROOT / 'checkpoints' / 'forecasting' / 'best_forecaster_hot.pth',
    ROOT / 'data' / 'Homo_sapiens_TF.html',
]

for p in required:
    print(f'{p}:', 'OK' if p.exists() else 'MISSING')

clf_cfg = load_yaml_config(ROOT / 'configs' / 'classifier_binary.yaml')
f_cfg = load_yaml_config(ROOT / 'configs' / 'forecasting.yaml')

print('cluster_col:', get_cluster_column())
print('time_col:', get_time_column())
print('cluster labels:', get_cluster_labels())
print('PV markers:', get_pv_identity_markers())
print('PV path:', get_pv_path_nodes())
print('classifier checkpoint:', clf_cfg['training']['checkpoint_path'])
print('forecasting checkpoint:', f_cfg['training']['checkpoint_path'])

# %%
import scanpy as sc
adata = sc.read_h5ad(ROOT / 'data' / 'labelled_data.h5ad')
print(adata)
print('obs columns:', list(adata.obs.columns)[:20])

# %% [markdown]
# ## Next
#
# - Run `01_classifier_analysis.ipynb` for classifier-side analysis.
# - Run `02_forecasting_analysis.ipynb` for forecasting/GRN-side analysis.
